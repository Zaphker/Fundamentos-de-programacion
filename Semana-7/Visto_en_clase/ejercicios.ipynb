# %%
archivo = open("saludo.txt", mode ="a")
archivo.write("4.- Cuarta linea para ejemplificar\n")
archivo.close()

print("Se ha escrito en el achivo saludo.txt")
# Out:
# Se ha escrito en el achivo saludo.txt

# %%
with open("bitacora.txt", mode="w") as archivo:
    archivo.write("Esto es una primera linea\n")
    archivo.write("Esto es una segunda linea\n")
    archivo.write("Esto es una tercera linea\n")
    
with open("bitacora.txt", mode="a") as archivo:
    archivo.write("Esto es una cuarta linea")

# %%
nombre = input("Ingrese su nombre: ")
edad = input("Ingrese su edad: ")

with open("datos_usuario.txt", mode="w") as archivo:
    archivo.write(f"Nombre: {nombre}\nEdad: {edad}\n")

print("Datos Guardados")
# Out:
# Datos Guardados

# %% [markdown]
# ## Lectura

# %%
with open("LCQSACLD.txt", mode="r") as a:
    contenido = a.read()
    print(contenido)
# Out:
# Hola buenos dias
# Esto es algo para leer
# viva la SDLG

# %%
with open("bitacora.txt", mode ="w") as a:
    a.write("Sistema Iniciado\n")
    a.write("Usuario Registrado\n")
with open("bitacora.txt", mode ="a") as a:
    a.write("Operacion guardada")
with open("bitacora.txt", mode="r") as a:
    contenido = a.read()
    print(contenido)
# Out:
# Sistema Iniciado
# Usuario Registrado
# Operacion guardada

# %%
with open("datos_usuario.txt", mode="r") as a:
    contenido = a.read()
    print(f"Contenido Original: \n{contenido}")
with open("datos_usuario.txt", mode="a") as a:
    a.write("Sobreescrito\n")
    a.write("Nuevo Valor\n")
with open("datos_usuario.txt", mode="a") as a:
    a.write("Adicional\n")
with open("datos_usuario.txt", mode="r") as a:
    contenido_nuevo = a.read()
    print(f"Contenido Nuevo:\n{contenido_nuevo}")
# Out:
# Contenido Original:
# Nombre: Hector
# Edad: 22
#
# Contenido Nuevo:
# Nombre: Hector
# Edad: 22
# Sobreescrito
# Nuevo Valor
# Adicional
